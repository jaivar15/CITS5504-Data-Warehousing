# %%
import pandas as pd

# %%
mobile_data = pd.read_csv("mobile_price.csv")

# %%
mobile_data.head()
# Out:
#    id  battery_power blue  clock_speed dual_sim  fc  four_g  int_memory  \
# 0   0            842   no          2.2       no   1       0           7
# 1   1           1021  yes          0.5      YES   0       1          53
# 2   2            563  yes          0.5      Yes   2       1          41
# 3   3            615  has          2.5       no   0       0          10
# 4   4           1821  yes          1.2       NO  13       1          44
#
#    m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0    0.6        188  ...         20       756  2549     9     7         19
# 1    0.7        136  ...        905      1988  2631    17     3          7
# 2    0.9        145  ...       1263      1716  2603    11     2          9
# 3    0.8        131  ...       1216      1786  2769    16     8         11
# 4    0.6        141  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen wifi  price_category
# ...

# %%
mobile_data.describe().T
# Out:
#                  count        mean          std    min      25%     50%  \
# id              2000.0   999.50000   577.494589    0.0   499.75   999.5
# battery_power   2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# clock_speed     2000.0     1.52225     0.816004    0.5     0.70     1.5
# fc              2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g          2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory      2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep           2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt       2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores         2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc              2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height       2000.0   645.10800   443.780811    0.0   282.75   564.0
# px_width        2000.0  1251.51550   432.199447  500.0   874.75  1247.0
# ...

# %%
mobile_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2000 non-null   int64
#  1   battery_power   2000 non-null   int64
#  2   blue            2000 non-null   object
#  3   clock_speed     2000 non-null   float64
#  4   dual_sim        2000 non-null   object
#  5   fc              2000 non-null   int64
#  6   four_g          2000 non-null   int64
#  7   int_memory      2000 non-null   int64
#  8   m_dep           2000 non-null   float64
#  9   mobile_wt       2000 non-null   int64
#  10  n_cores         2000 non-null   int64
#  11  pc              2000 non-null   int64
#  12  px_height       2000 non-null   int64
#  13  px_width        2000 non-null   int64
#  14  ram             2000 non-null   int64
#  15  sc_h            2000 non-null   int64
#  16  sc_w            2000 non-null   int64
# ...

# %% [markdown]
# There is no non-null values in the dataset. We can conclude that, there are

# %% [markdown]
# ### Data Cleaning

# %%
#drop the first column - id 
mobile_data = mobile_data.drop('id', axis = 'columns')
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
mobile_data.isnull().sum().sum()
# Out:
# 0

# %%
def rename_binary_attributes(data, attribute):
    for index in attribute:  
        data[attribute] = data[attribute].replace(['Yes', 'YES', 'has','Has','yes'],1)
        data[attribute] = data[attribute].replace(['NO', 'not', 'Not','No','no'],0)
    return data
mobile_data = rename_binary_attributes(mobile_data, ['blue','dual_sim','three_g','wifi'])

# %%
def drop_column(dataset, column_name):
    return dataset.drop(column_name, axis = 'columns')

# %%
mobile_data.to_csv('test.csv',index=False)
